# %% [markdown]
# <a href="https://colab.research.google.com/github/adityadhumal06/Computer_Vision/blob/main/Numpy_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('/content/Screenshot 2023-07-22 111433.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=490x383>

# %%
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img.mode
# Out:
# 'RGBA'

# %%
img_arr = np.array(img)
print(img_arr)
print(img_arr.shape)
# Out:
# [[[235 228 211 255]
#   [234 227 209 255]
#   [232 225 208 255]
#   ...
#   [183 183 175 255]
#   [184 182 174 255]
#   [186 182 174 255]]
#
#  [[236 229 212 255]
#   [235 228 210 255]
#   [233 226 209 255]
#   ...
#   [183 183 175 255]
#   [184 182 174 255]
#   [187 183 174 255]]
#
#  [[238 231 213 255]
#   [236 229 212 255]
#   [235 228 210 255]
#   ...
#   [183 182 174 255]
#   [184 182 174 255]
#   [187 183 175 255]]
#
#  ...
#
#  [[107  85  79 255]
#   [ 98  75  70 255]
#   [ 97  73  69 255]
#   ...
#   [229 223 212 255]
#   [224 223 213 255]
#   [221 226 218 255]]
#
#  [[ 95  73  68 255]
#   [ 84  61  57 255]
#   [ 82  58  54 255]
#   ...
#   [229 222 211 255]
#   [224 221 212 255]
#   [218 222 215 255]]
#
#  [[106  84  79 255]
#   [ 96  73  68 255]
#   [ 88  64  60 255]
#   ...
#   [224 220 213 255]
#   [219 219 213 255]
#   [211 214 210 255]]]
# (383, 490, 4)

# %%
plt.matshow(img_arr)

# %%
img1 = img_arr.copy()

# %%
img2 = img_arr.copy()

# %%
img3 = img_arr.copy()

# %%
img1[:,:,0]
# Out:
# array([[235, 234, 232, ..., 183, 184, 186],
#        [236, 235, 233, ..., 183, 184, 187],
#        [238, 236, 235, ..., 183, 184, 187],
#        ...,
#        [107,  98,  97, ..., 229, 224, 221],
#        [ 95,  84,  82, ..., 229, 224, 218],
#        [106,  96,  88, ..., 224, 219, 211]], dtype=uint8)

# %%
img1[:,:,0] = 0
plt.imshow(img1) # remove red color

# %%
img2[:,:,1] # green
# Out:
# array([[228, 227, 225, ..., 183, 182, 182],
#        [229, 228, 226, ..., 183, 182, 183],
#        [231, 229, 228, ..., 182, 182, 183],
#        ...,
#        [ 85,  75,  73, ..., 223, 223, 226],
#        [ 73,  61,  58, ..., 222, 221, 222],
#        [ 84,  73,  64, ..., 220, 219, 214]], dtype=uint8)

# %%
img2[:,:,1]=0
plt.imshow(img2)

# %%
img3[:,:,2]
# Out:
# array([[211, 209, 208, ..., 175, 174, 174],
#        [212, 210, 209, ..., 175, 174, 174],
#        [213, 212, 210, ..., 174, 174, 175],
#        ...,
#        [ 79,  70,  69, ..., 212, 213, 218],
#        [ 68,  57,  54, ..., 211, 212, 215],
#        [ 79,  68,  60, ..., 213, 213, 210]], dtype=uint8)

# %%
img3[:,:,2] = 0
plt.matshow(img3)
